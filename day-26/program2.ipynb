# %%
import pandas as pd 

df = pd.read_csv("https://raw.githubusercontent.com/B1u3B01t/Sales-Forecasting/main/predicted%20data/submission.csv")

df
# Out:
#                       Id  Weekly_Sales
# 0         1_1_2012-11-02  32161.720134
# 1         1_1_2012-11-09  19074.792232
# 2         1_1_2012-11-16  19182.855982
# 3         1_1_2012-11-23  20212.341018
# 4         1_1_2012-11-30  23585.831810
# ...                  ...           ...
# 115059  45_98_2013-06-28    672.065061
# 115060  45_98_2013-07-05    677.687085
# 115061  45_98_2013-07-12    686.158359
# 115062  45_98_2013-07-19    778.926305
# 115063  45_98_2013-07-26    712.302435
#
# [115064 rows x 2 columns]
