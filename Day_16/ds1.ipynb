# %%
pip install openpyxl
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import pandas as pd

df = pd.read_excel("https://github.com/singhrau0/Big-Data-Preprocessing/raw/main/superstore-subset.xlsx")
pd.set_option("display.max_columns", None)
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df['Product Sub-Category']

# %%
pip install seaborn
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 0.0/165.9 kB ? eta -:--:--
#      ------ ------------------------------ 30.7/165.9 kB 660.6 kB/s eta 0:00:01
#      ------ ------------------------------ 30.7/165.9 kB 660.6 kB/s eta 0:00:01
#      -------------------- ---------------- 92.2/165.9 kB 751.6 kB/s eta 0:00:01
#      -------------------- ---------------- 92.2/165.9 kB 751.6 kB/s eta 0:00:01
#      ------------------------ ----------- 112.6/165.9 kB 467.6 kB/s eta 0:00:01
#      -----------------------------------  163.8/165.9 kB 701.4 kB/s eta 0:00:01
#      -----------------------------------  163.8/165.9 kB 701.4 kB/s eta 0:00:01
#      ------------------------------------ 165.9/165.9 kB 474.6 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
# ...

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

sns.barplot(y = 'Product Sub-Category', x = 'Profit', data=df, estimator=len)
# Out:
# <Axes: xlabel='Profit', ylabel='Product Sub-Category'>
