# %%
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/main/titanic_dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Gender   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
len(df)
# Out:
# 891

# %%
# families()
# for i in range(len(df ['Ticket']));
# if df ['Ticket'] [i] not in families:
# else:
# families [df [Ticket 1 [11]=("cnt": 1, "members": [df ["Name"]] 1(111)
# families [df["Ticket'][i]]["cnt"]+1
# families [df [Ticket 1111]["members"].append(df['Name'][1])
# couples=[]
# for value in families.values():
# if value ("cnt">1):
# temp=[] females=[]
# males=[]
# for name in value "members"];
# if name.contains("Mrs."): if name. contains("("): females.append(nane)
# elif name. contains("Mr."):
# males.append(name [name. index ("Mr.")+3:).strip())
# form in males:
# for f in females:
# if f. contains (m):
# couples.append(["Mr. "em, fif.index("(")+1:f.index(")")]]).
# couples
# Out:
#   Cell In[1], line 3
#     if df Ticket'] [il not in families:
#                 ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
pip install openpyxl
# Out:
# ...
#    ---------------------------------------- 0.0/250.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/250.9 kB ? eta -:--:--
#    ------ -------------------------------- 41.0/250.9 kB 495.5 kB/s eta 0:00:01
#    ---------------------- ----------------- 143.4/250.9 kB 1.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 225.3/250.9 kB 1.5 MB/s eta 0:00:01
#    ---------------------------------------  245.8/250.9 kB 1.3 MB/s eta 0:00:01
#    -------------------------------------- 250.9/250.9 kB 962.7 kB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip list
# Out:
# Package           Version
# ----------------- -----------
# asttokens         2.4.1
# colorama          0.4.6
# comm              0.2.2
# debugpy           1.8.2
# decorator         5.1.1
# et-xmlfile        1.1.0
# executing         2.0.1
# ipykernel         6.29.5
# ipython           8.26.0
# jedi              0.19.1
# jupyter_client    8.6.2
# jupyter_core      5.7.2
# matplotlib-inline 0.1.7
# nest-asyncio      1.6.0
# numpy             2.0.0
# openpyxl          3.1.5
# packaging         24.1
# pandas            2.2.2
# parso             0.8.4
# pip               24.0
# platformdirs      4.2.2
# prompt_toolkit    3.0.47
# psutil            6.0.0
# pure-eval         0.2.2
# Pygments          2.18.0
# python-dateutil   2.9.0.post0
# pytz              2024.1
# pywin32           306
# pyzmq             26.0.3
# six               1.16.0
# stack-data        0.6.3
# tornado           6.4.1
# traitlets         5.14.3
# tzdata            2024.1
# wcwidth           0.2.13
# ...

# %%
import pandas as pd


dfx=pd.read_excel(r"C:\Users\A22308\Downloads\superstore-subset.xlsx")

# %%
dfx.head()
# Out:
#    Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0   18606  Not Specified      0.01        2.88           0.50            2
# 1   20847           High      0.01        2.84           0.93            3
# 2   23086  Not Specified      0.03        6.68           6.15            3
# 3   23087  Not Specified      0.01        5.68           3.60            3
# 4   23088  Not Specified      0.00      205.99           2.50            3
#
#      Customer Name    Ship Mode Customer Segment Product Category  ...  \
# 0  Janice Fletcher  Regular Air        Corporate  Office Supplies  ...
# 1    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 2    Bonnie Potter  Express Air        Corporate  Office Supplies  ...
# 3    Bonnie Potter  Regular Air        Corporate  Office Supplies  ...
# 4    Bonnie Potter  Express Air        Corporate       Technology  ...
#
#     Region State or Province       City  Postal Code Order Date  Ship Date  \
# ...

# %%
import openpyxl

dfx=pd.read_excel(r"https://github.com/singhrau0/Big-Data-Preprocessing/blob/raw/main/superstore-subset.xlsx")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# Cell In[12], line 3
#       1 import openpyxl
# ----> 3 dfx=pd.read_excel(r"https://github.com/singhrau0/Big-Data-Preprocessing/blob/raw/main/superstore-subset.xlsx")
#
# File c:\Users\A22308\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
#     497         storage_options=storage_options,
#     498         engine=engine,
# ...

# %%
import pandas as pd
import requests
from io import BytesIO

url = "https://github.com/singhrau0/Big-Data-Preprocessing/raw/main/superstore-subset.xlsx"

response = requests.get(url)
content = response.content

dfx = pd.read_excel(BytesIO(content))

# %%
pip install requests
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#    ---------------------------------------- 0.0/64.9 kB ? eta -:--:--
#    ------------------------- -------------- 41.0/64.9 kB 1.9 MB/s eta 0:00:01
#    ------------------------------------- -- 61.4/64.9 kB 1.1 MB/s eta 0:00:01
#    ---------------------------------------- 64.9/64.9 kB 501.7 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/163.0 kB ? eta -:--:--
#    ------- -------------------------------- 30.7/163.0 kB 1.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 92.2/163.0 kB 1.3 MB/s eta 0:00:01
#    ------------------------------------- -- 153.6/163.0 kB 1.1 MB/s eta 0:00:01
#    ------------------------------------- -- 153.6/163.0 kB 1.1 MB/s eta 0:00:01
#    -------------------------------------- 163.0/163.0 kB 697.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/100.4 kB ? eta -:--:--
# ...

# %%
import pandas as pd

# Updated raw GitHub URL
url = "https://github.com/singhrau0/Big-Data-Preprocessing/raw/main/superstore-subset.xlsx"

# Read Excel file into Pandas DataFrame
df = pd.read_excel(url)

# Now you can work with the DataFrame (df) as needed
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
pd.set_option('display.max_column', None)
df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
gt = df[['Product Sub-Category', 'Sales','Profit']].groupby('Product Sub-Category')

gt.agg({'Sales':['sum'],'Profit':['sum']}).sort_values(by = ('Sales','sum'), ascending= False)
# Out:
#                                      Sales         Profit
#                                        sum            sum
# Product Sub-Category
# Office Machines                 1218656.59  168072.833340
# Chairs & Chairmats              1164584.16  165348.882760
# Telephones and Communication    1144272.98  297950.524866
# Tables                          1061921.06  -72495.061875
# Copiers and Fax                  661211.93  129156.684030
# Binders and Binder Accessories   638582.09  226572.523042
# Storage & Organization           585704.91    8078.804727
# Bookcases                        507494.49   -7708.748564
# Computer Peripherals             490840.53   87917.842513
# Appliances                       456723.08  121651.391380
# Office Furnishings               444624.03   92209.225867
# Paper                            253600.31   35361.621738
# Envelopes                        147921.03   46133.223840
# Pens & Art Supplies              103251.59    1195.902840
# ...

# %%
# Compare Region wise total sales and profit of each region of each product category
gt = df[['Region','Product Category','Sales','Profit']].groupby(['Region','Product Category'])

gt.agg(['sum']).sort_values(by = ['Region',('Profit','sum')], ascending=[True, True])
# Out:
#                                Sales         Profit
#                                  sum            sum
# Region  Product Category
# Central Furniture          859217.62   55221.505013
#         Office Supplies    672768.64  167184.931602
#         Technology        1008355.36  297419.130452
# East    Furniture          864063.26   26216.090737
#         Office Supplies    711438.58  142792.437796
#         Technology         847302.84  208557.657511
# South   Furniture          546261.10   16981.587726
#         Technology         677134.59   28769.335748
#         Office Supplies    373950.53   58450.268946
# West    Furniture          909081.76   78935.114712
#         Office Supplies    500167.80   83562.578148
#         Technology         982189.24  148351.761037
