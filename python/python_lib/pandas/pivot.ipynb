# %%
import pandas as pd

df = pd.read_excel('superstore-subset.xlsx')

df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
pd.set_option('display.max_column', None)

df
# Out:
#       Row ID Order Priority  Discount  Unit Price  Shipping Cost  Customer ID  \
# 0      18606  Not Specified      0.01        2.88           0.50            2
# 1      20847           High      0.01        2.84           0.93            3
# 2      23086  Not Specified      0.03        6.68           6.15            3
# 3      23087  Not Specified      0.01        5.68           3.60            3
# 4      23088  Not Specified      0.00      205.99           2.50            3
# ...      ...            ...       ...         ...            ...          ...
# 9421   20275       Critical      0.06       35.89          14.72         3402
# 9422   20276       Critical      0.00        3.34           7.49         3402
# 9423   24491  Not Specified      0.08      550.98          45.70         3402
# 9424   25914           High      0.10      105.98          13.99         3403
# 9425   24492  Not Specified      0.09        7.78           2.50         3403
#
# ...

# %%
df.pivot_table(index=['Region', 'Product Category'], columns=['Customer Segment'], values=['Sales', 'Profit'], aggfunc=['sum'])
# Out:
#                                    sum                               \
#                                 Profit
# Customer Segment              Consumer      Corporate   Home Office
# Region  Product Category
# Central Furniture         13689.519290    8149.129656  11945.273016
#         Office Supplies   11966.975924   58798.635426  49171.626406
#         Technology        38624.632448  143178.419474  75113.872096
# East    Furniture          8587.041710    3702.619538  12866.936168
#         Office Supplies   23576.497414   61144.965780  24683.447914
#         Technology        29010.526762   80018.571618  40851.173156
# South   Furniture         14048.909723   -6041.518963   4408.951022
#         Office Supplies   12369.533746   32104.872434  17038.693509
#         Technology          139.428258   -2820.080010  18588.516660
# West    Furniture         31110.890942   23215.219640   3476.029760
#         Office Supplies   22723.017184   38235.848836   7645.594940
# ...
