# %% [markdown]
# ### PCA

# %%
import pandas as pd 

df = pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/main/Movie_Data.csv")

df
# Out:
#      Marketin_expense  Production_expense  Multiplex_coverage     Budget  \
# 0             20.1264               59.62               0.462  36524.125
# 1             20.5462               69.14               0.531  35668.655
# 2             20.5458               69.14               0.531  39912.675
# 3             20.6474               59.36               0.542  38873.890
# 4             21.3810               59.36               0.542  39701.585
# ..                ...                 ...                 ...        ...
# 501           21.2526               78.86               0.427  36624.115
# 502           20.9054               78.86               0.427  33996.600
# 503           21.2152               78.86               0.427  38751.680
# 504           22.1918               78.86               0.427  37740.670
# 505           20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
from sklearn.decomposition import PCA

pc = PCA(n_components = 5)

pc.fit(df.iloc[:,:-1])
# Out:
# PCA(n_components=5)

# %%
X = df.iloc[:,:-1]

# %%
from sklearn.preprocessing import StandardScaler

sd = StandardScaler()

X_sd = sd.fit_transform(X)

pc.fit_transform(X_sd)
# Out:
# array([[-1.37931112,  2.08009309,  0.432474  , -0.74535987, -1.68698043],
#        [-1.534756  , -0.58085621, -0.2432568 ,  2.0677328 , -0.08557919],
#        [-1.9183413 , -2.27889983, -2.40339919, -0.50957841,  1.27533153],
#        ...,
#        [ 1.06721088,  0.11154581, -1.37781392, -1.62689814, -0.94919178],
#        [ 1.29099466, -0.25814036, -1.38041861, -1.30839   ,  0.62260976],
#        [ 1.17744059, -0.57341326, -1.21818291, -1.08238213,  1.50626991]])

# %%
pct = PCA()

pct.fit(X_sd)
# Out:
# PCA()

# %%
exp_ratio = pct.explained_variance_ratio_

# %%
import numpy as np 

nsump = np.cumsum(exp_ratio)

# %%
import seaborn as sns

sns.lineplot(x= range(1, len(nsump)+1), y= nsump, marker='o')
# Out:
# <Axes: >

# %%
pct = PCA(n_components=11)

X = pct.fit_transform(X_sd)
