# %% [markdown]
# ### Simple Linear Regression

# %%
import pandas as pd 

df = pd.read_csv("https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/main/Movie_Data.csv")

df
# Out:
#      Marketin_expense  Production_expense  Multiplex_coverage     Budget  \
# 0             20.1264               59.62               0.462  36524.125
# 1             20.5462               69.14               0.531  35668.655
# 2             20.5458               69.14               0.531  39912.675
# 3             20.6474               59.36               0.542  38873.890
# 4             21.3810               59.36               0.542  39701.585
# ..                ...                 ...                 ...        ...
# 501           21.2526               78.86               0.427  36624.115
# 502           20.9054               78.86               0.427  33996.600
# 503           21.2152               78.86               0.427  38751.680
# 504           22.1918               78.86               0.427  37740.670
# 505           20.9482               78.86               0.427  33496.650
#
#      Movie_length  Lead_ Actor_Rating  Lead_Actress_rating  Director_rating  \
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

mx = MinMaxScaler()

df['trailer_encode'] = mx.fit_transform(df[['Trailer_views']])

df['trailer_encode']
# Out:
# 0      0.886108
# 1      0.792238
# 2      0.941576
# 3      0.854863
# 4      0.897608
#          ...
# 501    0.787800
# 502    0.760733
# 503    0.899837
# 504    0.797936
# 505    0.860947
# Name: trailer_encode, Length: 506, dtype: float64

# %%
x = list(df["trailer_encode"])
y = list(df["Collection"])

x
# Out:
# [0.8861082305732771,
#  0.7922377646024482,
#  0.9415761175860592,
#  0.8548631619288082,
#  0.8976081516715887,
#  0.8045520638427376,
#  0.694134786627291,
#  0.5295120494150004,
#  0.23179061746207086,
#  0.5610473635564374,
#  0.4415197592371335,
#  0.6727327036227148,
#  0.5484935413332132,
#  0.7314693748731936,
#  0.7957770689149891,
#  0.8023005478031516,
#  0.9000963727766632,
#  0.6151880114520164,
#  0.6633518564440136,
#  0.7056516152302802,
#  0.4456226470389323,
#  0.6888371018282647,
#  0.4919632994431796,
#  0.4291716449874884,
#  0.5670579814693749,
#  0.5902494420523458,
#  0.63091762663721,
#  0.5465463603778263,
#  0.6835365991117924,
#  0.7155791383935616,
#  0.38659009445659276,
#  0.6295058499966185,
#  0.24424299465722854,
#  0.5130159606844159,
#  0.4625216979643364,
#  0.7412954530084087,
#  0.7369445884713363,
#  0.7594879280416601,
#  0.8035009806352714,
#  0.9585371626952818,
#  1.0,
#  0.844191708559706,
#  0.8846119164092968,
#  0.7333179287179602,
# ...

# %%
x = [100, 200, 300, 400, 500, 800]
y = [3, 6, 8, 12, 20, 18]

# %%
a = 0.001
o1 = 0 
o0 = 0 
for k in range(1000):
    sum1 = 0 
    sum2 = 0
    for i,j in zip(x,y):
        ho1 = sum1 +((o0+(o1*i))-j)*i
        ho0 = sum2 +((o0+(o1*i))-j)
    do1 = ho1/len(x)
    do0 = ho0/len(x)
    o1 = o1 - (a*do1)
    o0 = o0 -(a*do0)
    print(o1, o0)
# Out:
# 3.289520990890698e-06 3.820816863636364e-06
# 6.579030661994779e-06 7.641620579209006e-06
# 9.868529013351197e-06 1.1462411146763173e-05
# 1.3158016044998905e-05 1.5283188566344108e-05
# 1.6447491756976855e-05 1.9103952837997058e-05
# 1.9736956149324e-05 2.2924703961767266e-05
# 2.3026409222079294e-05 2.6745441937699973e-05
# 2.631585097528169e-05 3.056616676584043e-05
# 2.960528140897014e-05 3.438687844623387e-05
# 3.28947005231836e-05 3.820757697892554e-05
# 3.618410831796101e-05 4.2028262363960694e-05
# 3.947350479334133e-05 4.5848934601384564e-05
# 4.276288994936351e-05 4.9669593691242396e-05
# 4.605226378606651e-05 5.3490239633579437e-05
# 4.934162630348927e-05 5.7310872428440924e-05
# 5.263097750167075e-05 6.11314920758721e-05
# 5.59203173806499e-05 6.49520985759182e-05
# 5.920964594046567e-05 6.877269192862449e-05
# 6.249896318115701e-05 7.25932721340362e-05
# 6.578826910276286e-05 7.641383919219856e-05
# 6.90775637053222e-05 8.023439310315683e-05
# ...

# %%
o1_res  = 0.0032838732246742294
o0_res = 0.003814256917534329 

x = 0.9415761175860592

# %%
(o1_res*x) + o0_res
# Out:
# 0.0069062735190679025

# %%
df = pd.read_csv('https://raw.githubusercontent.com/singhrau0/Big-Data-Preprocessing/main/bostandata%20(1).csv')

import seaborn as sns

sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
df.corr()
# Out:
#              crim        zn     indus      chas       nox        rm       age  \
# crim     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# zn      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# indus    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# chas    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# nox      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# rm      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# age      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# dis     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# rad      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# tax      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# ptratio  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %%
x = df['age']
y = df['lstat']

# %%
a = 0.001
o1 = 0 
o0 = 0 
for k in range(1000):
    sum1 = 0 
    sum2 = 0
    for i,j in zip(x,y):
        ho1 = sum1 +((o0+(o1*i))-j)*i
        ho0 = sum2 +((o0+(o1*i))-j)
    do1 = ho1/len(x)
    do0 = ho0/len(x)
    o1 = o1 - (a*do1)
    o0 = o0 -(a*do0)
    print(o1, o0)
# Out:
# 0.00030872200258181816 3.820816863636364e-06
# 0.000613460124655853 7.592328275443726e-06
# 0.0009142657759168059 1.1315170494019875e-05
# 0.001211189702646732 1.4989971567410049e-05
# 0.0015042819962760002 1.861735143905941e-05
# 0.0017935921018337796 2.2197922052398264e-05
# 0.0020791688262894754 2.573228745407767e-05
# 0.002361060346786525 2.9221043895872838e-05
# 0.0026393142187699416 3.2664779935271556e-05
# 0.0029139773840089755 3.606407653476455e-05
# 0.0031850961785162475 3.941950715985455e-05
# 0.0034527163403646924 4.273163787580065e-05
# 0.0037168830174036274 4.60010274431142e-05
# 0.003977640774875249 4.922822741182239e-05
# 0.004235033602932845 5.241378221451541e-05
# 0.0044891049240619865 5.555822925819291e-05
# 0.004739897600405955 5.866209901492519e-05
# 0.004987453940996638 6.172591511134453e-05
# 0.005231815708892113 6.47501944169816e-05
# 0.0054730241282221325 6.773544713146204e-05
# 0.005711119891142678 7.068217687057768e-05
# ...
